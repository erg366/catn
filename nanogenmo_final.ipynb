# %% [markdown]
# ### Computational Approaches to Narrative
# # *But to whom we are to form a full computer word.*
# NaNoGenMo entry by Emma Grimm

# %%
import random
import markovify
import tracery
from tracery.modifiers import base_english
import spacy
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# This program uses text from *Preliminary Specifications: PDP-3*, *IBM 1401 Programming Systems*, Plato's *The Republic* and William Walker Atkinson's *Your Mind and How to Use It: A Manual of Practical Psychology* to produce a 50,000 word output. In the initial draft, I combined all the input texts right away. When thinking about narrative structure, I realized that, because, in my head, the main subject of the output text is an imagined version of its author, the computer, most of the narrative would take place one level of abstraction above the actual text. I started thinking that a sort of narrative structure might emerge from form; that is, the very composition and format of the text at a given point in the narrative could point to the interiority of the subject. I decided that I should split up the processed input texts when reading them in and combine them in different amounts later on, to produce sentences, paragraphs and conversations with a different feeling to them. Below, I am reading in the different texts.

# %%
all_sentences = []
words = []
noun_chunks = []
entities = []

# %%
rep_sentences = []

the_republic_text = open("the_republic.txt").read()
republic_sent = the_republic_text.split(".")

rep_words = []
rep_noun_chunks = []
rep_entities = []
rep_name_entities = []
for i, sent in enumerate(random.sample(republic_sent, 1000)):
    rep_sentences.append(sent + ".")
    if i % 100 == 0:
        print(i, len(republic_sent))
    doc = nlp(sent)
    rep_words.extend([w for w in list(doc) if w.is_alpha])
    rep_noun_chunks.extend(list(doc.noun_chunks))
    rep_name_entities.extend(list(doc.ents))
# Out:
# 0 3734
# 100 3734
# 200 3734
# 300 3734
# 400 3734
# 500 3734
# 600 3734
# 700 3734
# 800 3734
# 900 3734

# %%
people = [e for e in rep_name_entities if e.label_ == "PERSON"]
namestring = ""
for entity in rep_name_entities:
    if entity in people:
        namestring += entity.text + " "
    else:
        rep_entities.append(entity)
print(namestring)
# Out:
# Zeus Thrasymachus Piraeus Glaucon Ariston Thrasymachus Polemarchus Thrasymachus Socrates Thrasymachus Odyssey Zeus Lycaean Zeus Priam Thrasymachus Thrasymachus Socrates Thrasymachus Shall halves?--doubles Socrates Socrates Musaeus Zeus Socrates Socrates Thrasymachus Achilles Socrates Atreus Lie Zeus Zeus Glaucon Behold Socrates Thrasymachus Thrasymachus Tis Agamemnon Socrates Polemarchus Socrates Socrates Piraeus Socrates Pray Polemarchus Eleusinian dissolution:--In Thrasymachus Polemarchus Glaucon Socrates Virtue Socrates Agamemnon Damon Glaucon Adeimantus Niceratus the Creator Glaucon Thrasymachus Glaucon God Socrates Zeus

# %%
ym_sentences = []

your_mind_text = open("your_mind.txt").read()
yourmind_sent = your_mind_text.split(".")

ym_words = []
ym_noun_chunks = []
ym_entities = []
ym_name_entities = []

for i, sent in enumerate(random.sample(yourmind_sent, 1000)):
    ym_sentences.append(sent + ".")
    if i % 100 == 0:
        print(i, len(yourmind_sent))
    doc = nlp(sent)
    ym_words.extend([w for w in list(doc) if w.is_alpha])
    ym_noun_chunks.extend(list(doc.noun_chunks))
    ym_name_entities.extend(list(doc.ents))
# Out:
# 0 2082
# 100 2082
# 200 2082
# 300 2082
# 400 2082
# 500 2082
# 600 2082
# 700 2082
# 800 2082
# 900 2082

# %%
people = [e for e in ym_name_entities if e.label_ == "PERSON"]
namestring = ""
for entity in ym_name_entities:
    if entity in people:
        namestring += entity.text + " "
    else:
        ym_entities.append(entity)
print(namestring)
# Out:
# bush reverie Adam joy,--but Halleck Halleck Desire Davidson James Bain Spencer William James Contrariwise Cinderella Cinderella Voluntary Anything Smiths Smith John Smith Gordy Smiths Smith Rule VI William James Thou James Brooks Brooks Darwin Darwin Hoffding Daydreams Benedict André vogel_ Hamilton Spencer John Fiske's John William James Halleck James Halleck Brooks hominem Huxley Aaron Burr William James Grant Allen Gordy Mill John Smith John Smith Jevons Major premise_)--A bird Brooks John Smith Henry Jones Davidson John Smith Paley

# %%
ibm_sentences = []

ibm_text = open("ibm-1401.txt").read()
ibm_sent = ibm_text.split(".")

ibm_words = []
ibm_noun_chunks = []
ibm_entities = []
ibm_name_entities = []

for i, sent in enumerate(ibm_sent):
    ibm_sentences.append(sent + ".")
    if i % 100 == 0:
        print(i, len(ibm_sent))
    doc = nlp(sent)
    ibm_words.extend([w for w in list(doc) if w.is_alpha])
    ibm_noun_chunks.extend(list(doc.noun_chunks))
    ibm_entities.extend(list(doc.ents))
# Out:
# 0 62

# %%
pdp_sentences = []

pdp_text = open("pdp-3.txt").read()
pdp_sent = pdp_text.split(".")

pdp_words = []
pdp_noun_chunks = []
pdp_entities = []
pdp_name_entities = []

for i, sent in enumerate(pdp_sent):
    pdp_sentences.append(sent + ".")
    if i % 100 == 0:
        print(i, len(pdp_sent))
    doc = nlp(sent)
    pdp_words.extend([w for w in list(doc) if w.is_alpha])
    pdp_noun_chunks.extend(list(doc.noun_chunks))
    pdp_entities.extend(list(doc.ents))
# Out:
# 0 732
# 100 732
# 200 732
# 300 732
# 400 732
# 500 732
# 600 732
# 700 732

# %% [markdown]
# ## Building Some Constituent Elements

# %% [markdown]
# - choral odes
# - conversations using markov chains from mixed text
# - more "authored" conversations with a clear topic, using tracery
# - markov chain text with varying compositions and coherence
# - program instructions (set the scene) ?
# - text converted to decimals ?

# %% [markdown]
# The problem with trying to hint at a narrative in this way is that whatever narrative there is, then, is very much contrived by me. If the narrative emerges from structural elements, and I am totally authoring the placement of those structural elements, is that really a narrative that was "computationally produced"? I don't think that this is a reason to abandon that approach entirely, because I still think the variable compositions of text add interest to the piece, but it made me think that there needed to be some other elements that imply some sort of story or progression. The nice thing about bringing new sources in as the text progresses is that it naturally introduces new entities and ideas which will then become recurring.

# %%
rep_text_gen = markovify.Text(rep_sentences, state_size=3)
ym_text_gen = markovify.Text(ym_sentences, state_size=3)
ibm_text_gen = markovify.Text(ibm_sentences, state_size=1)
pdp_text_gen = markovify.Text(pdp_sentences, state_size=3)

# %%
print(rep_text_gen.make_short_sentence(100,tries=100))
print(ym_text_gen.make_short_sentence(100,tries=100))
print(ibm_text_gen.make_short_sentence(100,tries=100))
print(pdp_text_gen.make_short_sentence(100,tries=100))
# Out:
# And is not this true of the mind's eye, quite as much as of the purity of the race.
# Likewise, one may form a mental image of such a will is to practice doing disagreeable things.
# _Branch Offices_ More than having to firms within a problem-oriented programming systems.
# The read-write check flag or the end of the following record.

# %%
part1_sent = []
part1_sent.extend(pdp_sentences)
part1_sent.extend(ibm_sentences)

part1_text_gen = markovify.Text(part1_sent, state_size = 2)

# %%
for i in range(3):
    print(part1_text_gen.make_short_sentence(30,tries=100))
    print(part1_text_gen.make_short_sentence(30,tries=100))
    print(part1_text_gen.make_short_sentence(100,tries=100))
# Out:
# This sets a program would.
# Each use of the machine.
# PAPER TAPE PUNCH The standard PDP-3 Paper Tape Punch and an Electric Typewriter.
# This new address is located.
# They may also be read.
# Accumulator The Accumulator is the key to profitable data processing.
# Bit 34 conditions hole #6.
# If the tape unit.
# The result is left in the right eight bits of the binary tape is either at the end of record.

# %%
part2_sent = []
part2_sent.extend(pdp_sentences)
part2_sent.extend(ibm_sentences)
part2_sent.extend(random.sample(rep_sentences,200))

part2_text_gen = markovify.Text(part2_sent, state_size = 2)

# %%
for i in range(5):
    print(part2_text_gen.make_short_sentence(100,tries=100))
    if random.randint(0,10) < 3:
        print(part2_text_gen.make_short_sentence(50,tries=100))
# Out:
# This information will remain at the normal range of room temperature.
# And do the work of these registers is available for the unit is ready.
# If the instruction is ignored.
# Address 0 is the central switching register.
# The education which was assigned to the operating time depends upon the device being used.
# The end of the Central Processor.
# A short example of a modern computing facility.

# %%
part3_sent = []
part3_sent.extend(pdp_sentences)
part3_sent.extend(ibm_sentences)
part3_sent.extend(random.sample(rep_sentences,400))
part3_sent.extend(random.sample(ym_sentences,100))

part3_text_gen = markovify.Text(part3_sent, state_size = 2)

# %%
for i in range(5):
    print(part3_text_gen.make_short_sentence(100,tries=100))
    if random.randint(0,10) < 3:
        print(part3_text_gen.make_short_sentence(200,tries=100))
# Out:
# _Deposit_ - The contents of octal digits 7 through 11.
# Yes, I replied, that our aim in founding the State in process of creation also.
# The overflow flip-flop equals ZERO or if they cannot command an army, they are really not the same pains with his art?
# In main memory, 511 of the soul, when choosing a new fashion.
# But do you not say that we are buried in deep thought concerning something far removed from the observed thing.
# Completion of the bodily state?
# It then recognizes the relation of the ideals of the soul?

# %%
part4_sent = []
part4_sent.extend(pdp_sentences)
part4_sent.extend(ibm_sentences)
part4_sent.extend(random.sample(rep_sentences,500))
part4_sent.extend(random.sample(ym_sentences,500))

part4_text_gen = markovify.Text(part4_sent, state_size = 3)

# %%
for i in range(5):
    print(part4_text_gen.make_short_sentence(100,tries=100))
# Out:
# And if merchandise is to be good or bad.
# The end of record flag.
# And have you further observed, that those who have the wit will doubtless forgive us.
# The fact is now recognized that the field of mental vision created by such focusing.
# , and may be regarded as a power of the imagination.

# %%
chorus_words = []

chorus_words.extend(ibm_words)
chorus_words.extend(pdp_words)
chorus_words.extend(random.sample(rep_words, 10000))

chorus_entities = []

chorus_entities.extend(ibm_entities)
chorus_entities.extend(pdp_entities)
chorus_entities.extend(random.sample(rep_entities, 400))

chorus_noun_chunks = []

chorus_noun_chunks.extend(ibm_noun_chunks)
chorus_noun_chunks.extend(pdp_noun_chunks)
chorus_noun_chunks.extend(random.sample(rep_noun_chunks, 2000))
chorus_noun_chunks.extend(random.sample(ym_noun_chunks, 1000))

# %%
nouns = [w for w in chorus_words if w.pos_ == "NOUN"]
chorus_verbs = [w for w in chorus_words if w.pos_ == "VERB"]
past_tense_verbs = [w for w in chorus_words if w.tag_ == 'VBD']
chorus_adjs = [w for w in chorus_words if w.tag_ == "JJ"]
chorus_advs = [w for w in chorus_words if w.pos_ == "ADV"]
chorus_people = [e for e in chorus_entities if e.label_ == "PERSON"]
chorus_locations = [e for e in chorus_entities if e.label_ == "LOC"]
chorus_times = [e for e in chorus_entities if e.label_ == "TIME"]
chorus_subjects = [chunk for chunk in chorus_noun_chunks if chunk.root.dep_ == 'nsubj']
chorus_objects = [chunk for chunk in chorus_noun_chunks if chunk.root.dep_ == 'dobj']

# %%
chorus_rules = {
    "subject": [w.text for w in chorus_subjects],
    "object": [w.text for w in chorus_objects],
    "verb": [w.text for w in chorus_verbs],
    "adj": [w.text for w in chorus_adjs],
    "adv": [w.text for w in chorus_advs],
    "ent": [w.text for w in chorus_entities],
    "people": [w.text for w in chorus_people],
    "loc": [w.text for w in chorus_locations],
    "time": [w.text for w in chorus_times],
    "origin": "\n\n\n\n#strophe#\n\n#antistrophe#\n\n#epode#\n\n\n\n",
    "strophe": "#sentence#\n#sentence#\n#sentence#\n#sentence#",
    "antistrophe": "#sentence#\n#sentence#\n#sentence#\n#sentence#",
    "epode": "#sentence#\n#sentence#",
    "sentence": [
        "[adjA:#adj#]#adjA.capitalize# #ent#, #adjA# #ent#",
        "[verbA:#verb#]#verbA.capitalize# #object#, #verbA# #object#",
        "#object# of #loc#",
        "no #ent#, no #ent# #verb#",
        "#adv# on #ent# he lies",
        "and #ent#'s #adj# form, and #subject# behind"
    ]
}

chorus_grammar = tracery.Grammar(chorus_rules)
chorus_grammar.add_modifiers(base_english)
print(chorus_grammar.flatten("#origin#"))
# Out:
# therefore on the Memory Address Register he lies
# no an Expense Distribution Report, no the In-Out Register would
# Invited the influence, invited houses
# Extra nn 65, extra TC
#
# the contents of earth
# when on 1401 he lies
# comma of earth
# and The Control Element's many form, and the skip behind
#
# and first's liberating form, and the case behind
# Octal Poseidon, octal State

# %% [markdown]
# ## Failed Experiment: Connector Sentences

# %% [markdown]
# I was trying to make it feel like one sentence flowed into the next more naturally by picking a noun out of each sentence and combining them in a statement that would go in between the two sentences, but I think it's much more pleasurable to imagine what the connection between two sentences might be. This kind of structure removes the charm of two generated sentences that unexpectedly lend meaning to one another.

# %%
sentA = part4_text_gen.make_short_sentence(100,tries=100)
sentB = part4_text_gen.make_short_sentence(100,tries=100)

# %%
print(sentA)
print(sentB)
# Out:
# * * * The Control Element governs the complete operation of the instruction is ignored.
# Tape control flags are examined to see that the tape is moved backwards a record.

# %%
sentAwords = sentA.split(" ")
sentBwords = sentB.split(" ")

sentAsubject = False
sentAobject = False
sentBsubject = False
sentBobject = False

for word in sentAwords:
    for subject in subjects:
        if word.strip(" ,.?!").lower() == subject.text:
            sentAsubject = word
    for obj in objects:
        if word.strip(" ,.?!").lower() == obj.text:
            sentAobject = word
            
for word in sentBwords:
    for subject in subjects:
        if word.strip(" ,.?!").lower() == subject.text:
            sentBsubject = word
    for obj in objects:
        if word.strip(" ,.?!").lower() == obj.text:
            sentBobject = word
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5d2a3cf4084b> in <module>
#       8
#       9 for word in sentAwords:
# ---> 10     for subject in subjects:
#      11         if word.strip(" ,.?!").lower() == subject.text:
#      12             sentAsubject = word
#
# NameError: name 'subjects' is not defined

# %%
connector = ""

if (sentAsubject):
    if (sentBsubject):
        connector = sentAsubject.capitalize() + " is an expansion of what " + sentBsubject + " brought up."
    elif (sentBobject):
        connector = sentBobject.capitalize() + " must also be considered as " + sentAsubject + "states."
elif (sentBsubject):
        connector = sentBsubject.capitalize() + "explained it thus."

# %%
print(sentA + " " + connector + " " + sentB + "\n\n\n\n\n\n")
# Out:
# If the TC is connected to the right to rule of either, both in states and individuals.  DECAL is an open-ended programming system and can be expanded to drive 64 modules.

# %% [markdown]
# ## Writing "Conversations"

# %%
def speaker():

    speaker_string = "« "

    num = random.randint(0,10)

    if num < 3:
        speaker_string += part3_text_gen.make_short_sentence(100,tries=100) + " "
    elif num < 6:
        speaker_string += part3_text_gen.make_short_sentence(50,tries=100) + " "
    else:
        speaker_string += part4_text_gen.make_short_sentence(50,tries=100) + " "

    for i in range(random.randint(0,3)):
        if random.randint(0,10) < 5:
            speaker_string += part3_text_gen.make_short_sentence(70,tries=100) + " "
        else:
            speaker_string += part4_text_gen.make_short_sentence(70,tries=100) + " "

    speaker_string += "» \n\n"

    return speaker_string

# %%
for i in range(10):
    if i % 2 == 0:
        print(speaker())   
    else:
        print("   " + speaker())
# Out:
# « The high order digits of the current memory cycle. Yes, I said, that you mean houses, he replied. The compiler will be very much disputed. »
#
#
#    « Yes, he said, and assent. Bit four conditions hole #1. »
#
#
# « Repeated operation of the machine. »
#
#
#    « Emotion, however, as a rule, just and wise. TIP allows the typewriter to be used with the instructions. »
#
#
# « Psychology is generally considered to be a tyrant. _Stop_ - The computer will resume operation of the machine. »
#
#
#    « Is there not exceptions? The information is left in the soul of the register being left clear. That, he replied, may be a great comforter. »
#
#
# « Put the question in your own spirit. 1401 Programming Systems can accomplish. »
#
#
#    « The computer will resume operation of the machine. And now since we have made them as you say. Each core memory are available as index registers. This is a counting register operated by a factor of that pulse. »
#
#
# « Both together will they proceed? This is achieved by means of the operate instruction. »
#
#
#    « Now, then, if I have made them as you say. »

# %%
conversation_words = []

conversation_words.extend(ibm_words)
conversation_words.extend(pdp_words)
conversation_words.extend(random.sample(rep_words, 10000))

conversation_entities = []

conversation_entities.extend(ibm_entities)
conversation_entities.extend(pdp_entities)
conversation_entities.extend(random.sample(rep_entities, 400))

conversation_noun_chunks = []

conversation_noun_chunks.extend(ibm_noun_chunks)
conversation_noun_chunks.extend(pdp_noun_chunks)
conversation_noun_chunks.extend(random.sample(rep_noun_chunks, 2000))
conversation_noun_chunks.extend(random.sample(ym_noun_chunks, 1000))

# %%
conversation_nouns = [w for w in conversation_words if w.pos_ == "NOUN"]
conversation_verbs = [w for w in conversation_words if w.pos_ == "VERB"]
conversation_past_tense_verbs = [w for w in conversation_words if w.tag_ == 'VBD']
conversation_adjs = [w for w in conversation_words if w.tag_ == "JJ"]
conversation_advs = [w for w in conversation_words if w.pos_ == "ADV"]
conversation_people = [e for e in conversation_entities if e.label_ == "PERSON"]
conversation_locations = [e for e in conversation_entities if e.label_ == "LOC"]
conversation_times = [e for e in conversation_entities if e.label_ == "TIME"]
conversation_subjects = [chunk for chunk in conversation_noun_chunks if chunk.root.dep_ == 'nsubj']
conversation_objects = [chunk for chunk in conversation_noun_chunks if chunk.root.dep_ == 'dobj']

# %%
conversation_rules = {
    "subject": [w.text for w in conversation_subjects],
    "object": [w.text for w in conversation_objects],
    "verb": [w.text for w in conversation_verbs],
    "adj": [w.text for w in conversation_adjs],
    "adv": [w.text for w in conversation_advs],
    "ent": [w.text for w in conversation_entities],
    "people": [w.text for w in conversation_people],
    "loc": [w.text for w in conversation_locations],
    "time": [w.text for w in conversation_times],
    "origin": "[topicA:#object#][topicB:#object#]#conversation#",
    "conversation": ["« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n",
                     "« #speaker# »\n\n   « #speaker# »\n\n« #speaker# »\n\n   « #speaker# »\n\n"
                    ],
    "speaker": ["#sentence# #sentence# #sentence# #sentence#",
                "#sentence# #sentence# #sentence#",
                "#sentence# #sentence#",
                "#sentence#"
               ],
    "sentence": [
        "Yes.",
        "No.",
        "That's #adv# not about #topicB#: #clause#",
        "The #thing# with #topicA# is that #clause#",
        "#topicA.capitalize# is #adj#, that is to say #clause#",
        "Have you considered #topicB#?",
        "No #topicB# before #topicA# is #adj#."
        "Well, #topicA# will #adv# #verb# because #topicB# is #adj#."
        "#topicB.capitalize# #verb# to #topicA#, that means #clause#",
        "#clause.capitalize# So #topicA# is #adj#.",
        "#clause.capitalize# And #topicB# is #adj#.",
        part3_text_gen.make_short_sentence(50,tries=100),
        part3_text_gen.make_short_sentence(70,tries=100),
        part3_text_gen.make_short_sentence(90,tries=100),
        part4_text_gen.make_short_sentence(50,tries=100),
        part4_text_gen.make_short_sentence(70,tries=100),
        part4_text_gen.make_short_sentence(90,tries=100)
    ],
    "clause": [
        part3_text_gen.make_short_sentence(50,tries=100).lower(),
        part3_text_gen.make_short_sentence(70,tries=100).lower(),
        part3_text_gen.make_short_sentence(90,tries=100).lower(),
        part4_text_gen.make_short_sentence(50,tries=100).lower(),
        part4_text_gen.make_short_sentence(70,tries=100).lower(),
        part4_text_gen.make_short_sentence(90,tries=100).lower()
    ],
    "thing": ["issue", "problem", "fact", "concern", "truth"]
}

conversation_grammar = tracery.Grammar(conversation_rules)
conversation_grammar.add_modifiers(base_english)
print(conversation_grammar.flatten("#origin#"))
# Out:
# « No its energies before you is previous.Well, you will however circumstanced because its energies is full.Its energies tries to you, that means but how will they proceed? Have you considered its energies? Have you considered its energies? »
#
#    « Such an one be a slave in the soul. »
#
# « Have you considered its energies? The Program Counter is indexed one extra position and the change in our State. »
#
#    « The features include request for printing of a series of mental and physical reactions. »
#
# « Three registers of toggle switches are available as index registers. »
#
#    « Emotion, however, as a rule, just and wise. Three registers of toggle switches are available as index registers. The original contents of octal digits to be given. So you is main. Yes. »
#
# « Three registers of toggle switches are available as index registers. Emotion, however, as a rule, just and wise. »

# %% [markdown]
# ## Assembling the Text

# %% [markdown]
# None of these outputs are really have much coherence, and there is no computationally produced narrative structure. I'm sort of disappointed in this project but I can't work on it any more or I'll scream.

# %%
print(chorus_grammar.flatten("#origin#"))

for i in range(200):
    print(part1_text_gen.make_short_sentence(30,tries=100))
    for i in range(5):
        if random.randint(0,10) > 9:
            print()
            
for i in range(300):
    if random.randint(0,10) < 5:
        print(part1_text_gen.make_short_sentence(100,tries=100))
    else:
        print(part1_text_gen.make_short_sentence(50,tries=100))
    for i in range(5):
        if random.randint(0,10) > 9:
            print()
            
print(chorus_grammar.flatten("#origin#"))

for i in range(200):
    if random.randint(0,10) < 5:
        print(part1_text_gen.make_short_sentence(30,tries=100))
    else:
        print(part2_text_gen.make_short_sentence(50,tries=100))
    for i in range(5):
        if random.randint(0,10) > 9:
            print()
            
print(chorus_grammar.flatten("#origin#"))
            
for i in range(100):
    if random.randint(0,10) < 3:
        print(part1_text_gen.make_short_sentence(30,tries=100))
    else:
        print(part2_text_gen.make_short_sentence(100,tries=100))
    for i in range(5):
        if random.randint(0,10) > 9:
            print()
            
for i in range(10):
    paragraph = ""

    for i in range(random.randint(1,5)):
        if random.randint(0,10) < 3:
            paragraph += part2_text_gen.make_short_sentence(30,tries=200) + " "
        else:
            paragraph += part2_text_gen.make_short_sentence(100,tries=100) + " "

    print(paragraph + "\n\n\n")

print(chorus_grammar.flatten("#origin#"))

for i in range(10): 
    for i in range(20):
        paragraph = ""

        for i in range(random.randint(2,10)):
            if random.randint(0,10) < 3:
                paragraph += part3_text_gen.make_short_sentence(30,tries=200) + " "
            else:
                paragraph += part3_text_gen.make_short_sentence(100,tries=100) + " "

        print(paragraph + "\n\n")

    for i in range(random.randint(6,12)):
        if i % 2 == 0:
            print(speaker())   
        else:
            print("   " + speaker())
            
    print(chorus_grammar.flatten("#origin#"))

for i in range(20): 
    for i in range(20):
        paragraph = ""

        for i in range(random.randint(2,10)):
            if random.randint(0,10) < 3:
                paragraph += part4_text_gen.make_short_sentence(50,tries=200) + " "
            else:
                paragraph += part4_text_gen.make_short_sentence(100,tries=200) + " "

        print(paragraph + "\n\n")

    for i in range(random.randint(1, 4)):
        print(conversation_grammar.flatten("#origin#"))
            
    print(chorus_grammar.flatten("#origin#"))
    print(chorus_grammar.flatten("#origin#"))

for i in range(50):
    print(chorus_grammar.flatten("#origin#"))
    print(part3_text_gen.make_short_sentence(100,tries=100))
    print()
    print(part3_text_gen.make_short_sentence(100,tries=100))
    print()
    print()
# Out:
# the format of earth
# the bits of earth
# no 5, no third can
# no one, no guardians harmed
#
# when on 0 he lies
# various format print outs of earth
# and N's dangerous form, and  The simplicity behind
# why on Test he lies
#
# the arithmetic operations of earth
# the function of earth
#
#
#
#
# The binary point are: 1.
# The details of the machine.
# It contains the answer.
# This new address is located.
# The MPS order is first given.
# Bit four conditions hole #8.
#
# The sign of the product.
# It does not take place.
# Space is available for PDP-3.
#
# The character is typed.
#
# A unit is available.
#
# The binary point are: 1.
# The MPS order on the computer.
# The end of the instruction, i.
# The program can be repeated.
# There is no selection.
# Examples of the Accumulator.
# The character is typed.
#
# At the same operation code.
#
# In addition to the operator.
#
# A unit is ready.
# It uses a stored program.
# Bit 28 conditions hole #1.
#
# Similarly the output mode.
#
# Since the index registers.
# It contains the answer.
# Examples of the in-out wait.
# This tape is punched.
#
# A break to a suitable routine.
#
# 70 If the memory register Z.
# This new address is located.
# When the TC buffer.
#
# The program is written by IBM.
#
# The Memory Addressing Element.
#
# This new address is located.
# The end of record.
# The result is left blank.
#
#
#
# None
#
#
#
#
# The indirect address bit.
# Bit 28 conditions hole #6.
#
# The first bit of the machine.
# If at any time.
#
#
# Completion of the machine.
#
# This tape is punched.
# Bit four conditions hole #8.
# If the tape unit.
# The character is typed.
# Similarly the output mode.
#
# If no flags set.
#
# , lines with no flags set.
# The #8 hole is ignored.
# Greek symbols are permitted.
# Bit 34 conditions hole #1.
# This is a stored program.
#
# Thus the program halts.
#
# If at any time.
# The result is left blank.
#
# The end of record flag.
#
#
# This tape is punched.
# The MPS is given.
# Bit 28 conditions hole #1.
# This sets a program flag.
# One bit of the product.
# If at any time.
#
# If, after the MPS is given.
# The MPS is given.
# The instructions in less time.
# Bit four conditions hole #1.
# If a flag is set.
#
# Greek symbols are permitted.
# It does not take place.
# This new address is located.
# At the same operation code.
# If at any time.
#
# Bit zero conditions hole #1.
#
#
# This tape is punched.
#
# 3 is a switch.
#
# The computer will start.
# Greek symbols are permitted.
# Bit four conditions hole #1.
#
# , the position indicated by Y.
#
# Examples of the Accumulator.
# The TC will be left clear.
#
#
# The sign of the operator.
# The character is typed.
# Bit zero conditions hole #1.
# If a flag is set.
#
#
# Bit zero conditions hole #8.
# Thus the program halts.
#
# The MPS order on the Console.
#
# Bit 28 conditions hole #1.
# 70 If the TC buffer.
#
# The result is left blank.
# The character is typed.
# The binary point are: 1.
#
# The binary point are: 1.
# The result is left blank.
# There is no selection.
# The character is typed.
# If at any time.
# The clock can be written.
#
# The end of record flag.
#
# The MPS is given.
#
# There is no selection.
#
#
# Bit 28 conditions hole #1.
#
# Bit 28 conditions hole #1.
# When the TC buffer.
#
# Thus the program halts.
#
# The end of record gap.
# A unit is ready.
#
# Similarly the output mode.
#
# Bit zero conditions hole #1.
# It does not take place.
# If the TC buffer.
# Similarly the output mode.
#
# If at any time.
# The computer will start.
# The end of record gap.
# This tape is punched.
# A break to a floating number.
#
# Greek symbols are permitted.
#
# All flags must be punched; i.
# A unit is ready.
#
# There is no selection.
# Bit 34 conditions hole #6.
# The clock can be repeated.
# Greek symbols are permitted.
# The instructions in less time.
# This tape is punched.
#
# There is no selection.
#
# The MPS order is first given.
# Bit 34 conditions hole #8.
#
# Bit 34 conditions hole #6.
# This instruction is 5 +0.
# Since the index registers.
# A break to a suitable routine.
# If the tape unit.
# 4 is a switch.
# The end of record gap.
# Bit 28 conditions hole #6.
#
# The clock can be repeated.
# If the in-out wait.
# The binary point are: 1.
#
#
#
# Bit zero conditions hole #8.
# The end of record gap.
#
# Z may be compiled separately.
#
# The information is left blank.
# Similarly the output mode.
#
# The end of record.
#
# This moves the tape unit.
#
# The TC will be left clear.
# The result is left blank.
# The #8 hole is ignored.
# This sets a program flag.
#
# The length is a single szo.
#
#
#
# Completion of the Accumulator.
# Bit zero conditions hole #8.
#
# If the instruction is skipped.
# If the tape unit.
# The sign of the machine.
# The binary point are: 1.
# The #8 hole is ignored.
# Bit four conditions hole #6.
# The contents of the machine.
#
# Bit four conditions hole #6.
#
# The program is written by IBM.
#
# There is no selection.
# Bit four conditions hole #1.
# Similarly the output mode.
#
# There is no selection.
# Bit 34 conditions hole #8.
# , the position indicated by Z.
#
# A break to a suitable routine.
#
# Z may be read in this mode.
#
# Greek symbols are permitted.
# The computer will start.
# It is a Light Pen.
# The result is left blank.
# Bits 0-9 of the transfer.
# If at any time.
#
# Bit 34 conditions hole #1.
#
# It contains the answer.
# The instructions in less time.
#
# The result is left blank.
# At the same operation code.
# Thus the program halts.
#
# Greek symbols are permitted.
# The Memory Addressing Element.
# The end of tape is punched.
# Bit four conditions hole #1.
# If this bit is a Light Pen.
#
# For each In-Out Transfer.
#
# If no flags set.
# A unit is first given.
# If the instruction word.
# Bit 34 conditions hole #1.
# At the same operation code.
# In addition to the TC buffer.
# If the memory register Z.
#
# All flags must be punched; i.
# nn 60 mrb Read a binary number to a standard floating number.
# They are used to locate a memory register Z.
# , the position indicated by Z.
# With IBM you can be expanded to drive 64 modules.
#
# The subroutines are provided with PDP-3.
#
# Equipment Frame The Equipment Frame or may be performed automatically by subroutines.
#
# These will include programs written by the program.
# It provides a means of the In-Out Register.
# Index Adder or the output mode.
# Octal digit 6 of Y are left in the Accumulator.
# The binary point is to be given.
#
#
# Thus, a high speed channel is given and the operate instruction.
#
# The MPS order given during writing each time an MPS order is given for approximately 5 milliseconds.
#
# Other changes to the number allows magnitude comparisons to be sensed.
#
# Bit four conditions hole #6.
#
# A cable connects the Console to the TC is connected to a tape control handles the programming staff.
# DECAL is an example of this counter may be read at any time.
#
# Most in-out operations require a plug board.
#
# If at any time Program Flag Number One is set.
#
#
# The details of the memory register indicated in the last point displayed.
#
# Information is read or written will occupy.
#
# Operations for floating point arithmetic.
# Rotate is a 15 bit Index Adder which is ZERO for positive numbers.
#
# The Index Adder also serves as the address after being modified by deferring or by indexing.
#
# The motion commands have the same operation code.
#
# The end of record gap.
# When the two numbers are handled by programming.
# The #8 hole is ignored.
# _Continue_ - The computer will operate in the Accumulator.
# They may also be read.
#
# There is a switch.
#
# REAL TIME CLOCK A special input register may be equal to Y or it may be defined once.
#
# This sets a write alphanumeric into the right end of record.
# The binary point are: 1.
# The Program Counter are lost.
# nn 60 mrb Read a binary number to binary, convert a binary record.
# To read a record may be initiated by the program.
# A tape unit and the tape moves at 75 inches/sec.
# Index registers may be read in this mode.
# This addition is done by subroutine.
#
# Thus the program pauses until information can be reset to zero by manual operation.
#
# If, after the MWA or MWB order.
# This includes the time of that pulse.
#
# _Writing a Record of Information_ Information is written on each inch of tape is punched.
# A smaller display is similar to that of the registers can be written.
#
# The high speed channel is given for approximately 5 milliseconds.
# If a flag is set during reading or writing.
#
# The result is left with the instructions.
#
#
# Each core memory are available on the Console.
# The index address, X, is in the Accumulator.
# Similarly the output mode.
# The operation of the Arithmetic Element.
# 2N microseconds, where N is the indirect address also has a cycle time of 5 microseconds.
# Thus the program is on Page 29.
#
#
# The #8 hole is ignored.
# If the tape unit.
#
# This new sequence may be used for simulating time delays.
#
# The index address, X, is in the Accumulator.
# Similarly the output mode.
#
# =Here's how one of the instruction, i.
#
# Another IOT command synchronizes the transfer of data processing systems.
# The end of record gap.
# All flags must be executed for information to its original address unmodified.
# The result is left in the new command.
#
#
# For each In-Out Transfer.
#
# The #8 hole is ignored.
# 4 is referred to in the sequence is skipped.
#
# Three-quarter inches of blank tape is spaced forward n records.
#
# The high order digits of the instruction word.
#
#
# Bit 34 conditions hole #8.
# At this time, an MPS instruction is given.
#
# OPTIONAL INPUT-OUTPUT The PDP-3 Cathode Ray Tube Display is useful for maintenance purposes.
# Each inactive tape transport requires 10 amperes.
# An incidental fact which may be defined once.
#
# Rotate is a function of the IO to be executed.
#
# The character is typed.
# The simplicity of the internal operation.
#
# Bit zero conditions hole #1.
# One bit of octal digits 3, 4, and 5.
# The high order digits of the dividend is in the last point displayed.
# When the Single Cycle Switch is on, the computer will resume operation of the separate skips.
#
# Octal digit 6 of Y are left unchanged.
# Octal digit 6 of the dividend and is a non-arithmetic cyclic shift.
# If the tape is arranged so as to be used to indicate separate states of a program.
# Information is read or written will occupy.
#
# This new address is located.
# The index address, X, is in the Accumulator.
# Thus the program halts.
# Bit zero conditions hole #8.
# Each inactive tape transport requires 10 amperes.
#
#
#
# Digits 0-5 of the product.
# These are generalized instructions, particularly useful in debugging programs.
#
# A tape unit and the program restarts immediately.
# Maximum time for completion, the computer will start.
#
# _Subroutines_ These are generalized instructions, particularly useful in debugging programs.
# 70 If the instruction following the jsp.
#
# When the TC information buffer.
# Repeated operation of PDP-3 instructions are normally multiples of the In-Out Register is positive.
# The Memory Addressing Element.
# For each In-Out Transfer instruction.
# When the MPS is given.
#
# It incorporates in one system all of them with you.
# All flags must be punched; i.
#
# This tape is written in standard FRAP language.
# When MEC is given, the tape is punched.
# A unit is ready.
# There is no selection.
# The method of operation of this device the computer to the tape is punched.
# The high speed for further memory expansion.
#
# The MPS is given.
#
# The Report Program Generator is an advanced symbolic programming system.
#
#
# Octal digit 6 of the In-Out Register.
#
# The high speed for further memory expansion.
# It is also part of the Memory Address Register, and the computer.
#
# _Connection with High Speed Channel_ The high speed channel directs the tape comes to the TC buffer.
# That is, the completion of the instruction, i.
#
#
# The Sense Switches are present for manual deposit into memory.
# The binary point is to be defined once.
# Operations for floating point arithmetic.
# It provides a means of a modern computing facility.
# 1401 Programming Systems can accomplish.
# The TC will be left clear.
# The high speed channel connected to a particular sequence may be utilized for programming.
#
# 36 rotate steps of the In-Out Register are unaffected by the indexing process.
# The control contains a 36 bit length.
# With IBM you can be expanded to drive 64 modules.
# This speed, together with its original position.
#
# In-Out Register bit five conditions hole #2, etc.
#
#
# The flags are: parity, end of record gap.
# The read-write check flag or the output mode.
#
# The octal digits 7 through 11 of Z are lost.
# Three registers of the main sequence.
# Operations for floating point arithmetic.
# Address 10 senses the position of the Accumulator.
#
# The standard PDP alphanumeric paper tape reader will operate in the Test Address Switches.
# The left 6 bits plus a parity bit, are written in IBM 729I format.
# This new address is located.
# Thus, a high speed channel connected to the standard input-output equipment.
# If the TC information buffer.
#
# The first two are used to locate the operand.
# This includes the title of the Accumulator.
# The clock can be executed.
# One bit of the product.
#
# Information is read or written will occupy.
# This sets a program flag.
# After the subroutine has been read correctly.
# Bit 28 conditions hole #6.
# The binary point when converting a binary record.
# A smaller display is similar to the machine.
#
#
# While the machine may be utilized for programming.
# CATHODE-RAY-TUBE DISPLAY The PDP-3 is a switch.
# Six lines form the standard computer instructions.
# It can operate in the register were a ring.
# A typical program loop for handling an in-out device, the program, or an external signal.
#
# At the same operation code.
#
# Three special instructions snx, spx and lir, are available for the instruction sequence.
#
# The contents of the internal operation.
#
# An incidental fact which may be utilized for programming.
# A break to a standard floating number.
# In certain instructions, the skip to occur.
# A cable connects the Console which are used.
#
#
# Since the index register or an external signal.
# This speed, together with the input mode or the output mode.
# Each inactive tape transport requires 10 amperes.
#
# Bits 0-9 of the instruction word.
# After the subroutine has been read correctly.
# This tape is either at the end of record flag is set.
# Six lines form the inclusive OR of the machine.
# The Core Memory may be a free-standing frame.
# Most in-out operations require a plug board.
#
# The #8 hole is ignored.
#
# It contains the answer.
#
# _Test Switch_ - When the Test Address Switches are present for manual deposit into memory.
# Each inactive tape transport requires 10 amperes.
# The result is left blank.
#
# In-out class commands instruct TC to the operating time depends upon the device being used.
# The actual position of the addressing section of the remainder of the computer.
# Figure 4 is a function of the Central Processor.
# In certain instructions, the skip instructions, and the Equipment Frame.
# Greek symbols are permitted.
#
# The binary point may be connected to the relative duty factor of that particular flip-flop.
#
# Index registers may be defined once.
# The layout of the Accumulator.
#
# Bit zero conditions hole #2, etc.
# The Core Memory may be checked for correct parity while writing.
#
#
# The arithmetic subroutines are: add, subtract, deposit, load, etc.
#
# 3 is a photograph of PDP-1 which is to the right six bits of the number of shifts.
# That is, the completion of each memory cycle.
#
# A break to a tape is read or written.
# The transfer of information between a tape unit cabinet may be defined once.
#
# Similarly the output mode.
#
# The next instruction to be given.
# _ _The combination of a modern computing facility.
#
# Bit zero conditions hole #2, etc.
# Octal digit 6 of the memory location indicated by Z.
#
# Program Flags act as index registers.
# It is a stored program.
# Figure 4 is a stored program.
#
# The computer will start.
# _COBOL_ COBOL is a counting register operated by a higher priority sequence.
# This flip-flop is not at the end of the memory register indicated in the Read-In mode.
#
# If a flag is set in the sequence is skipped.
# Service that has been read correctly.
# _ _The combination of a modern computing facility.
# This flip-flop is cleared by this technique.
#
# If an instruction is skipped.
# Upon completion of the internal operation.
# The following program is on Page 29.
# This time may be read at any time Program Flag Number One is set.
#
# The in-out transfer command indicates the nature of the transfer will signal the proper sequence.
# The TC will be taken from a program until six characters are assembled in the Accumulator.
#
# These will include programs written by the Test Address will be skipped over.
#
# The computer will start.
# FRAP allows mnemonic symbols to be easily interpreted visually in terms of machine instruction.
# The high speed for further memory expansion.
#
#
# The end of record flag.
# The TC will be skipped over.
# The original address, Y, is in the TC cause the skip.
# The octal digits to be transferred.
# It contains the controls and indicators for the instructions.
# If the in-out function.
#
# The left half of these methods staffs.
# , when octal digits 0-5 of the second operand.
#
# Completion of the register were a ring.
# A tape unit and the Memory Buffer lights.
#
# The character is typed.
# There is no limit to the TC if a motion order is given for the instructions.
# 3 is a close-up of the binary tape is moved backwards a record.
#
# INSTRUCTION FORMAT The instructions in less time.
# Using the floating point number to a standard floating number.
# The layout of the instruction, i.
# The address portion of the memory address digits, Y, and in some cases the index registers.
# This new address is located.
#
# The TC contains a one line buffer.
# The MPS is given.
#
# Communication is done by subroutine.
# Console The Console is a photograph of PDP-1 which is to the right six bits of the machine.
# Non-indexable memory instructions 2.
#
#
# If the in-out function.
#
# The first bit of octal digits 0-5 of the dividend.
# Using the floating point arithmetic.
# Program Flags act as index registers.
#
# 1401 Programming Systems can accomplish.
# , the position of the second operand.
# The sign of the machine.
# Of particular interest is the number of words to be a free-standing frame.
#
# The simplicity of the machine.
# Industry seminars where customers meet to discuss all of the current memory cycle.
#
# A short example of a modern computing facility.
# Thus, if address 3000 is selected, the skip instructions, and the operate group.
#
# The contents of the positive numbers.
# If a flag is then a no-operation command.
# Tape control flags are examined and modified.
# The address portion of the Equipment Frame.
#
# A cable connects the Console which are used.
# This display uses a stored program.
# 4 is a space in the Test Word Switches will be used in conjunction with the programming staff.
# Examples of the end of the in-out wait.
# The contents of octal digits to be sensed.
# The simplicity of the register were a ring.
# The next instruction in an easily remembered form.
# A break to a suitable routine.
# Hole #7 is left in the last point displayed.
# It also has a cycle time of 5 microseconds.
# The result is left in the In-Out Register.
#
# The original contents of the separate skips.
#
# In this case, the address of an installation.
# Similarly the output mode.
# Bit 34 conditions hole #6.
# The TC contains a one line of tape is read or written will occupy.
#
# If a tape unit 10, j is unknown.
# Programming is unaffected during reading or writing.
# The flags are: parity, end of record gap.
# These mnemonic symbols to be given.
# Carry Storage Register, performs address bookkeeping for the programmer.
# The left half of these registers is available for use as automatic index registers.
#
# It uses a stored program.
#
# If at any time.
#
# Bit zero conditions hole #1.
#
#
#
# The octal digits 0-5 of the separate skips.
#
# This new address is located.
#
# This addition is done in the specification of new programming systems.
#
# The contents of the registers can be executed.
# This enables management to communicate more easily with the input or output devices.
#
# The Core Memory may be a free-standing frame.
#
#
# Console The Console is a function of the instruction will not take place.
# Figure 4 is a Light Pen.
#
# The pattern of holes in the sequence is skipped.
# The address portion of the positive numbers.
# , when octal digits 0 and 1 define the instruction is usually a jump to another program.
# It contains the answer.
# They facilitate the transfer of data processing experience.
# Address 10 senses the position of the separate skips.
#
# If the tape is punched.
#
# Digits 0-5 of the register being left clear.
#
# This control, termed the Sequence Break System is connected, the completion of the product.
# If a tape unit number 04, is shown.
# It is also part of the product are left unchanged.
#
# Index Adder The Index Adder or the output mode.
#
# CATHODE-RAY-TUBE DISPLAY The PDP-3 consists of modules of 4096 words of memory.
#
#
#
#
#
#
# Whole twenty-two inches, whole six
# no dio x/d         , no two read
# the previous content of the
# earth
# and a few minutes Polemarchus's absolute form, and  This last instruction behind
#
# thus on 19 he lies
# Will the high order digits, will the change
# and 10's indirect form, and who behind
# the responsibility of earth
#
# commonly on Arcadian he lies
# now on six he lies
#
#
#
#
# , the position of the main magnetic core storage.
# Bit 34 conditions hole #1.
# They may also be read.
#
# Bit four conditions hole #6.
#
# Repeated operation of the machine.
#
# If the memory register Z.
# The next instruction to be given to laughter.
#
# The method of operation of the dividend.
# Bit four conditions hole #1.
# If an instruction is ignored.
#
# This speed, together with the rest.
# Bit 28 conditions hole #6.
# The Core Memory may be set_ MWA 3 ms.
#
# The details of the instruction, i.
#
#
#
# Since they operate on the setting of the computer.
#
# Now he was one of the memory register Z.
# If a flag is set in the treatment of the race.
#
# If no flags set.
# Then you must join.
# Greek symbols are permitted.
# The character is typed.
# Examples of the Accumulator.
# The high speed for further memory expansion.
# The instructions in less time.
# Bits 0-9 of the following instruction.
# For example, they are not simultaneous do not.
# This instruction is given.
# Similarly the output mode.
#
# Similarly the output mode.
# It contains the answer.
# It contains the Control Element.
# A break to a floating number.
# Whereas the wise and good?
# The result is left blank.
# If, after the MPS is given.
# The program is written by IBM.
# They will go with the input or output devices.
# , lines with no flags set.
# Bit four conditions hole #8.
# The sign of the dividend.
# If the instruction is given.
#
#
#
# The subroutines are provided with PDP-3.
#
# If an instruction is given.
# The computer will start.
# , lines with no flags set.
# There is no selection.
#
# _Halt_ hlt Address 400 This instruction is 5 +0.
#
#
#
# Then if the nature of the sexes.
# And if the TC buffer.
#
# Information is written by IBM.
# The TC will be skipped over.
# The instructions in less time.
# Operations for floating point arithmetic.
#
#
# Bit zero conditions hole #8.
# This addition is done in the sequence is skipped.
# Bit 0 is no selection.
#
# Bit zero conditions hole #1.
#
# If an instruction is given.
# Bit 28 conditions hole #2, etc.
# We will not take place.
# The sign of the computer.
# Bit zero conditions hole #8.
# The instructions in less time.
# Greek symbols are permitted.
# Bit four conditions hole #1.
# Bit 34 conditions hole #1.
# The binary point are: 1.
#
# And now, I said, at your fear of the Accumulator.
# I agree with me.
# Rotate is a switch.
# Each inactive tape transport requires 10 amperes.
# There is no selection.
# Greek symbols are permitted.
#
# The people are a third address is located.
# Bit 28 conditions hole #6.
# They must not be goodly or fortunate.
#
# At the same operation code.
# But I suppose so.
# If the tape unit.
# There is no selection.
# The control contains a 36 bit length.
# They may also be read.
#
# _COBOL_ COBOL is a 15 bit ring accumulator.
# The #8 hole is ignored.
#
# DECAL is an eye of a guardian, and another not.
#
#
# They may also be perfectly clear?
#
# If the TC buffer.
# The character is typed.
# Similarly the output mode.
# Those again who are to have both these qualities?
#
# There is no selection.
# Statements about the things beneath.
# How do you mean by the appropriate iot.
# Rotate is a Light Pen.
# The Program Counter are lost.
#
# Tape control flags are examined and modified.
# TIP allows the typewriter in either direction.
# They may also be perfectly clear?
#
# The sign of the instruction is skipped.
# The addition is done by subroutine.
#
# I think that I could! but you must join.
#
# For each In-Out Transfer.
# The instructions in less time.
# Bit zero conditions hole #1.
# Bit zero conditions hole #1.
#
#
# Bit 34 conditions hole #1.
# Bit zero conditions hole #1.
# Nothing in the individual.
#
# The end of record.
#
# This sets a program would.
# Hole #7 is left in the sequence is skipped.
# This is an example of this kind which we speak.
# The next instruction in an easily remembered form.
# Bit four conditions hole #1.
# That will be put in the sciences?
# If an instruction is 5 +0.
# The result is left blank.
# The Program Counter are lost.
#
# And of women and children?
# A unit is available.
#
# PDP-3 is a Light Pen.
# This In-Out Transfer instruction.
# Bit zero conditions hole #1.
# I agree with me.
# At the same operation code.
# The end of record flag.
# Bit zero conditions hole #8.
# The x portion of the slow mechanical action.
#
#
# Bit zero conditions hole #1.
# If no flags set.
# Bit zero conditions hole #8.
# Space is available for PDP-3.
#
# A unit is ready.
# They may also be read.
#
# _Unit Availability_ A unit is first given.
# Non-indexable memory instructions 2.
# The #8 hole is ignored.
# Then when the tape moves at 75 inches/sec.
# This new address is located.
#
# A unit is ready.
#
# Examples of this display is available.
# Then the wise and good?
# At the completion of the machine.
# Greek symbols are permitted.
# It does not take place.
# Thus the program halts.
# Index registers may be defined by the lights.
# The Accumulator is the central switching register.
#
# Then the wise and good to every one!
# 4 is a switch.
#
# The next instruction in the Accumulator.
# The people are a third address is located.
# The MPS order on the Console.
# Repeated operation of the two.
# The result is left blank.
# , lines with no flags set.
# And as to obtain reports swiftly and efficiently.
# Bit 34 conditions hole #8.
# If this bit is a Light Pen.
#
# And yet, I said, as we have now said enough.
# If no flags set.
#
# The record length is a switch.
# The following program is written on tape.
# The simplicity of the machine.
# It uses a stored program.
# The remainder is in the binary tape is punched.
#
# This addition is done by subroutine.
#
# This new address is located.
# Greek symbols are permitted.
# Rotate is a stored program.
# Bit four conditions hole #8.
# They may also be read.
# There is no selection.
# The character is typed.
#
#
# Now he was one of the end of record gap.
# In certain instructions, the skip to occur.
#
# Pray, consider whether I am good for.
#
# The Memory Buffer Register.
#
#
# , the position indicated by Y.
# The left 6 bits plus a parity check has occurred.
#
# Octal digit 6 of the Equipment Frame.
# The MPS order on the computer.
# FRAP-3 may also be read.
# It contains the answer.
#
# Not, he said, I agree.
# The sign of the computer.
#
# They may also be read.
#
#
# The computer will start.
#
# If an instruction is given.
# The layout of the product.
# The result is left in the quotient, respectively.
# Bit 28 conditions hole #6.
#
# Greek symbols are permitted.
#
# Then you must join.
#
# The record length is a benefit to us?
# If at any time.
# At the same operation code.
# Bit zero conditions hole #8.
#
# The clock can be written.
# If no flags set.
#
#
#
#
#
# Indicates the possible results, indicates a Paper Tape Reader
# swiftly on May he lies
# Such FORMAT, such Real Time Clock
# Opposite PDP-3, opposite first
#
# Manual BCD, manual guardians
# a jump of earth
# Then on third he lies
# Provides a length, provides the influence
#
# Arithmetic 1, arithmetic one
# Young ax2^b, young one
#
#
#
#
# Why, I said, that men and women are to share in the argument?
# The instructions in less time.
# This is a stored program.
# Such is the sign of the State, it will be destroyed.
# And how can one who owes money to his cleverness?
# _Tape Utilities_ These are just a few of the In-Out Register.
# nn 64 mwb Write a binary number to binary, convert a binary record.
# Yes, he said; but to what is not.
#
# But when Polemarchus and I had forgotten, I should not deserve to hear more.
# Bit zero conditions hole #1.
# If no Sequence Break System_ When the TC is free, the command waits until it can be repeated.
# Index registers may be defined once.
#
# If the instruction is ignored.
#
# This new address is located.
#
#
# Hole #7 is left in the sequence is skipped.
# In main memory, 511 of the reel, or a part only?
#
# You may remember, I said, the judge should not be discovered by an in-out halt as required.
#
# It contains the answer.
# For when your guardians are ignorant of the gods cannot be indexed.
# The binary point are: 1.
# INSTRUCTION FORMAT The instructions in less time.
# Are not the many IBM services.
# _Subroutines_ These are generalized instructions, particularly useful in debugging programs.
# The machine is asynchronous for in-out operations, that is, of one thing, and halves of another?
# Binary Mode ppb iot 6 For each In-Out Transfer variations are listed below.
# Bit four conditions hole #6.
#
# The operation of the Arithmetic Element.
#
# Service that has been already remarked by us; for of all new programming systems.
# It is a 15 bit 1's complement arithmetic.
#
# 3 is a finger all the switches.
# The character is typed.
# The clock can be repeated.
# The contents of octal digits 0 through 5 of Y are left unchanged.
# This new sequence may be written which handle complex floating numbers and PDP-3 floating numbers.
# _Test Switch_ - When the two you are so disposed I will be left clear.
# Another IOT command synchronizes the transfer will signal the proper sequence.
# Address 0 is no limit to the want of a program.
# Certainly not, I said, is not easy to imitate or to have the wit will doubtless forgive us.
# The addition is done by subroutine.
#
# The index register to specify the variations in any office or command.
# The high order digits of the instruction following the jsp.
# Index Adder or the output conversion of binary numbers into the IO.
#
# This is a switch.
# Bit 34 conditions hole #6.
#
#
# And of women and children?
# As being the least significant.
# In these, the PDP-3 to perform floating point numbers are handled by programming.
#
# Completion of the instruction word.
#
# Memory cabinets may be connected to the operating push buttons.
#
# Bit 0 is no selection.
#
# In-Out Register is the indirect address for the unit.
#
# There is no difficulty in discerning her in the Accumulator.
#
# The conversion of binary numbers into decimals is done in the binary point are: 1.
#
# Then, I said, can there be in his religious duties?
# At this time, an MPS is restarted, information is left in the In-Out Register.
# If an instruction is 5 +0.
#
# If an instruction is given.
#
# Tape control flags are examined and modified.
#
# Hole #7 is left in the acquisition of knowledge of any kind.
# And has not the same word format as the indexable instructions.
# The address portion of the system design restraint.
#
# _Writing a Record of Information_ Information is read and assembled in a priority chain.
# The x portion of the computer will operate properly over the normal case.
# The Memory Addressing Element.
#
#
# And has not the good; the good are useless has now been explained?
#
# The first bit of octal digits 7 through 11 act as index registers.
# Bit 28 conditions hole #1.
#
# Programming is unaffected during reading or writing.
#
# MISCELLANEOUS ROUTINES A variety of materials for imitation?
# The clock can be executed.
#
# The original address, Y, is in effect multiplication of the separate skips.
#
# A tape unit cabinet may be added at any time by virtue of the Accumulator.
# And therefore our politic Asclepius may be truly said to enchant.
#
# The TC will be at hand.
#
# A flexible loader is available in the treatment of the dividend.
#
# I listened in admiration, and wanting to be perfectly clear?
#
# There is no selection.
# The program is written on each inch of tape is punched.
# 70 If the in-out function.
# The education which was assigned to best fit his source language.
#
# 3 is a switch.
# If no flags set.
#
# In those instructions which do not include the optional in-out halt.
#
#
# The remainder is in the memory cycle is taken to serve the channel.
# The binary point are: 1.
#
# May we say that they were to be called a war?
# If the instruction word.
# The conversion of binary numbers into the binary point is to be called a war?
# The state of this and the reader continues moving.
#
# The machine is asynchronous for in-out operations, that is, of one thing, and halves of another?
# Bit four conditions hole #1.
# The operation of the Accumulator and the flags cleared.
# Optional in-out devices and the reader continues moving.
#
# You agree then, I said, all these qualities, which we were saying that for you not to me.
# The record length is a finger is a space in the Test Address Switches.
#
#
# And in so far as I understand, he said, that there will be destroyed.
# The Program Counter are lost.
#
#
# This switch is operated, the computer to the higher, lower, and middle notes of the operator.
#
# Is not his case utterly miserable? and does not the same principle hold in the Accumulator.
# nn 64 mwb Write a binary number to a particular sequence may be set_ MWA 3 ms.
#
# PDP-3 is designed to accommodate a variety of materials for imitation?
#
#
#
# The TC will be skipped over. Not, he said, I agree. The main memory makes 511 registers of 36 bit word is shown in Fig. If the memory address digits, Y, and in a theatre.
#
#
#
# Bits 0-9 of the world. Indexable memory instructions 3. This In-Out Transfer normally should not be discovered by an in-out command.
#
#
#
# For which the satisfaction is a desk approximately seven feet long. The simplicity of the memory register Z. Similarly the output mode.
#
#
#
# Two common conventions in the new command. And therefore our politic Asclepius may be Y as modified by deferring or by indexing. Thus, communications between parts of the instruction sequence.
#
#
#
# Bits 0-9 of the product. If a motion command is given before information actually enters the TC can handle the transfer. Similarly the output mode. Figure 4 is a 15 bit Index Adder is a non-arithmetic cyclic shift.
#
#
#
# An illustration will make him a school of medicine such as the indirect address bit. They must not the good; the good of their young ones will be very much disputed. I agree with me. Similarly, the break is initiated by the latter words.
#
#
#
# Well, but has been _proven_ by years of data is taking place.
#
#
#
# If this bit is a Light Pen. If an instruction includes reference to an in-out halt as required. It contains the high order digits of the slow mechanical action.
#
#
#
# _Halt_ hlt Address 400 This instruction is usually a jump to another program. Thus, communications between parts of the machine.
#
#
#
#
#
#
#
# Latter 6, latter third
# the return of TC
# Binary 10, binary Thracians
# Rewinding a
# reflex action, Rewinding the TC buffer
#
# Require their own mind, require his words
# Then on second he lies
# and 6's sick form, and their contents behind
# and guardians's just form, and he behind
#
# Remember the function, remember the
# unit
# and operate='s free form, and I behind
#
#
#
#
# The character is typed. Rotate is a single szo. For few are the best of life? And what are you alluding? And will they be compelled. If the in-out function. I listened in admiration, and wanting to be perfectly clear? Is the attempt to construct one?
# The end of the State. Is there not exceptions? The subroutines are provided with PDP-3.
#
#
# I proceeded to ask: When two things, a greater extent than he imagines himself to be. Yes, he replied, is excellent. I mean, I replied, that our rulers will not mind wallowing like a hero, and nobody sees or cares? If this bit is a Light Pen.
#
#
# Still, he replied, has greatly the advantage; for he has any, are soon spent. , the position indicated by Y. Have you not see that men are changed by a corruption of the absolute diameter, and so they ought. The tube is equipped with a minimum of time and effort. They are used to specify the unit word transfers. Thus, communications between parts of the Thracians was equally, if not more, beautiful. Why, where can they come there? That is, the completion of each memory cycle. When this device delivers its completion, the operating time of the forehead. The next instruction in the easiest and quickest manner; not implanting the faculty of the computer.
#
#
# Then the soul to reason about them, they are to be wise and good? The read-write check flag or the number of registers the words read or written. In addition to the program is on Page 29. Shall we begin by taking the State and have now arrived at the procession. It is the greatest. If then we adhere to our friends and associates of a shopkeeper! This tape is written by IBM.
#
#
# Then more husbandmen and more perfectly than they have been set, the following conditions: 1. The end of record flag. Nor would you call evil? The original contents of the following instruction. But, on the Console. I perceive, I said, reflect. But we have given them: and in the In-Out Register. Both together will they be compelled. In connection with this natural order? Repeated operation of the instruction will not do for me; I am good for.
#
#
# A program designed to accept a camera or photomultiplier device. Whereas, I said, how in the sequence will be required? If no flags set. And God proclaims as a program until the unit is ready. And are you alluding? If the TC buffer. Address 10 senses the position of the least significant digits in the sequence is skipped.
#
#
# But when a man besides taking away the fear of death? Hole #7 is left in the soul. The state of the stronger. But we should be on his guard against her seductions and make friends with it. If no flags set. Well said, Cephalus, I replied; justice, which is good, he said. Done to me!--as becomes the ignorant, I must have a good guardian who is not, not. And all arithmetic and calculation have to do good to our bodily wants?
#
#
# , lines with no flags have been from their youth upwards, if we mean them to remember them. This sequence must include an iot instruction which has an opinion in accordance with measure? Upon completion of the transfer. Additional subsets may be utilized for programming. This switch is primarily useful for presentation of graphical or tabular information to its object. Can any man be courageous who has knowledge know something or nothing? The state of this book. The program begins in register d, using tape unit cabinet may be sampled and changed simultaneously. And if merchandise is to be laid to the rulers, and rulers who are not simultaneous do not.
#
#
# Similarly the output mode. He is a Light Pen. And these two, thus nurtured and educated, and you will answer well. The character is typed. The original contents of octal digits 7 through 11. Very good; and if we say that this is the situation of the instruction sequence. This tape is punched.
#
#
# These, I said, they ought not. In division it starts with the beard of a certain piece of music, to dawn upon thousands of persons. _Examine_ - The computer will come back to him? An incidental fact which may be freely intermixed with symbolic machine language instructions. _Sense Switches_ - There are three in number. This combination is achieved by the indexing process.
#
#
# A unit is ready. You are right, he said. If, after the MPS is given. MAINTENANCE ROUTINES Maintenance Routines are used in a story will often cause the skip. What do you now model the form of a formula translation compiler. The program can set, clear, or sense the individual as well as commercial. But there are many other proofs; but to see that men and women are to share in the order.
#
#
# Bit 34 conditions hole #6. The binary point is to you a matter of indifference.
#
#
# In multiplication it ends with the PDP-3 and is not this true of the other so-called goods of life? Does the just man? In the same way, the family group may be readily allowed, and is true. Still, he replied, there would be read in this register. The simplicity of the In-Out Register. It is through these languages that the image of the Accumulator. This sequence must include an iot instruction which has a nominal speed of 20 lines per second. Why, of course you won't.
#
#
# And as to what manner will the imitator have either? Since they operate on the availability and use of the mind.
#
#
# That they must have. The address portion of the operate instruction.
#
#
# But is the main sequence. Well-tested programming languages for communication with external equipment. But do you conceive the guardians will never get beyond the stage of empty gesture making. There is the end of the mind. Nor would you expect, I said, that men and women are so fond of rehearsing. Programming is unaffected during reading or writing. And as the latter the complex. I imagine not, he said. Or because a stork has long legs and a long, tapering horn, spirally twisted, in the soul.
#
#
# Therefore, I said, reflect. The end of record. Since few characters limit or control the format of information from the individual flip-flops. And has not of any other; they have only to be the subject is required to execute the new command.
#
#
# Is there not exceptions? Will you repay me, then, what you show him--that is about 100,000 operations per second. It will repeat this instruction specifies the in-out wait.
#
#
# The education which was assigned to the operating push buttons, there are in every way perfect? Index registers may be readily allowed, and is not a few.
#
#
# « _Anything_ may be used to locate the operand. And now, I said, my dear Socrates,--those of them, he said. Who can imagine that a man who is to be kept pure. »
#
#
#    « The computer has a very serious task. Repeated operation of the machine. »
#
#
# « The end of record gap. There cannot be indexed. Instead, it is used to locate the operand. »
#
#
#    « A little change in our office, house, or in the order. The end of record flag. »
#
#
# « Digits 0-5 of the index registers. Or, if the In-Out Register are unaffected by this instruction. That will be the most miserable of States? The end of record flag. »
#
#
#    « Repeated operation of the machine. I fear that I should imagine so. »
#
#
# « When necessary, a memory register Z. Octal digit 6 of the memory cycle of 5 microseconds. _Utility Programs_ These are just and would not be the truth. »
#
#
#    « It will be found, as a rule, just and wise. »
#
#
# « In connection with this natural order? »
#
#
#
#
#
#
# and four's young form, and I behind
# their hold of earth
# usually on NEARLY he lies
# no the year, no twenty years effects
#
# and 2's eager form, and what behind
# Own MPS, own 10
# the programmer of TC
# perfectly on the age of thirty he lies
#
# Used whom, used herself
# no two, no 7 aiming
#
#
#
#
# I said: but I should not. The method of inference. Greek symbols are permitted. Bit 28 conditions hole #1. An index register address of the dividend. Yes; that is the normal case. Quite true, he replied.
#
#
# Bit 0 is the process? The method of inference.
#
#
# The end of record. The pleasure of gain? After the subroutine has been turned in the new sequence. But, at the moment. Address 1 selects program flag 1, 02 clears program flag one, etc.
#
#
# Statements about the dead, pretending that they would shipwreck? The Index Adder is a problem-oriented programming language for commercial applications. For a line to be a general.
#
#
# At all events we are rejoiced at his having it? This command has the power of abstraction. Then opinion and knowledge have to be used as automatic index registers. And if we are to be executed. Well, but what ought to be temperate and the next instruction deposits the IO. The high order part of the line are read. This sets a program would. I mean in the Accumulator. If at any time.
#
#
# Still, I said, do you mean? These digits address an index register to specify the address of the register are unchanged. Why, of course you won't. Then there is a switch.
# Can you tell me? The Core Memory may be utilized for programming. To read a record with the computer. 1401 Programming Systems can accomplish. The details of the dividend. This includes the time of the dividend. Bit zero conditions hole #1. Memory cabinets may be used for simulating time delays.
#
#
# I am really just and would not be those who are supposed to possess the truth? But will you explain yourself? _Halt_ hlt Address 400 This instruction is ignored. Still, he replied, has greatly the advantage; for he has any, are soon spent. Problem oriented language statements may be of advantage. Of particular interest is the excellence of the right of the instruction, i.
#
#
# This sum is negative, the Program Counter. If the in-out wait. For there is nothing else than the good. Yes; and is not a mere sailor? Why, of course they are. A short example of a real bed, not a mere sailor?
#
#
# From no point of asking why are the goods of human life, and many a one. Then, I said, how in the arts. Then, I said, let me tell you my view about them. But of course they are. Z may be formed. OPTIONAL INPUT-OUTPUT The PDP-3 consists of modules of 4096 words of memory. MECHANICAL DESCRIPTION The PDP-3 is designed to handle various major data processing systems. And will any one who is trained in the place of the mind. I imagine not, he said. Then do you not see that information on tape has moved backwards a record.
#
#
# The average person may be connected to a standard floating number. There is no one is willingly deceived in that place.
#
#
# The MPS is given. There are other fallacies which will be manifested more clearly. And will they be compelled. A unit is ready. The left half of these generalized sorting routines. On completion, the operating push buttons. It lists minimum time before completion pulse is identical with the low order parts of the soul?
#
#
# Space is available in the double duty. The computer will start. Yes, he said; I am good for. _COBOL_ COBOL is a Light Pen.
#
#
# The result is left blank. _Sense Switches_ - There are the goods of life? The end of record gap. In-out class commands instruct TC to the TC cause the skip does not gradually thaw. Index Adder The Index Adder also serves as the companions and friends and harm to our bodily wants?
#
#
# The end of record gap. Then, again, there is to you to be transferred. A tape unit cabinet may be compiled separately. How do you say? Without the power of abstraction. PDP-3 is a bird. But do you say?
#
#
# I proceeded to ask: When two things, a greater extent than he imagines himself to be. DECAL is an exact reproduction of the mind, or soul, divinely given. In-out class commands instruct TC to the end of record gap. And when they have no true or not? The clock can be repeated. Can any man be courageous who has knowledge know something or nothing?
#
#
# Bit zero conditions hole #2, etc. Service that has been _proven_ by years of data between IBM cards, magnetic tapes, and printers. But, at the audience. Tape control flags are examined and modified. And may we not right in saying that the time of the methods of developing perception, given in time. Very good; and if any help be sent by his friends to the tape is written in IBM 729I format. When the MPS order is given and the computer. And is not derived from the severity of study than from the IO. The addition is done by subroutine.
#
#
# Bits 1 to 9 the exponent, and the next instruction in the descent from nature an imitator? The TC will be required? And will any one deny this? But of course they are. But how will they proceed? A program designed to handle various major data processing experience. In what way, then, will our youth dwell in a day. Likewise, one may form a full computer word.
#
#
# Greek symbols are permitted. And is he awake? Yes, he said, can be repeated. At the completion of an assembler, and the subject and ally? This tape is not in his character. If the in-out wait. The program can be added to the democratic man. Two common conventions in the individual they pass into the IO. INDEXING In PDP-3, 511 registers available as index registers.
#
#
# ...
#
# The education which was assigned to best fit his source language.
#
#
#
#
#
#
# and 4's inclusive form, and he behind
# then on MWA he lies
# no Solon, no five specify
# and Scythian's fellow form, and no unit behind
#
# even on 10 he lies
# Obtain Utility Programs, obtain the capacity
# the program of earth
# and TC's same form, and Program Flag One behind
#
# thus on six he lies
# floating point operations of earth
#
#
#
#
# Various conditions occurring in the past; and as having happened in our State.
#
# At the completion of multiplication it holds to be included in the Accumulator.
#
#
#
#
#
#
# no States, no N ignored
# no the Central Processor, no two following
# early on State he lies
# Drawn the
# unit, drawn 6 bits
#
# and 10's next form, and I behind
# no State, no N  Operation Code 662 said
# Stocked the mental state, stocked the Major Total
# no two, no Two take
#
# Defined the
# preparation, defined a full computer word
# and 5's new form, and later psychology behind
#
#
#
#
# Would any one who is trained in the laws which we were founding do you not praise me?
#
# Who can imagine that this is the process?
#
#
#
#
#
#
# the patience of earth
# the
# thing of earth
# justice of earth
# no 5, no COBOL obtain
#
# and EOR's previous form, and : 1) Four MWA commands behind
# Written a binary record, written any
# other violence
# and first's public form, and  I behind
# Connected all
# poetry, connected me
#
# and PROCESSOR's wealthy form, and mnemonic symbols behind
# Parable one, parable State
#
#
#
#
# The end of record gap.
#
# Yes, that appears to be told, and others when they are glad to be a difficulty in saying which.
#
#
#
#
#
#
# no State, no 1 operating
# True Accumulator, true third
# Combined the following definitions, combined all 1401 customers
# no two, no State require
#
# Suitable 60, suitable one
# Good Y  Operation Code 52, good 3
# currently on 36 he lies
# Said TAPE READER, said this number
#
# Know clearer and
# truer inferences, know all
# poetry
# indeed on five inch he lies
#
#
#
#
# They will be to establish a censorship of the soul, not pure unadulterated falsehood.
# INSTRUCTION FORMAT The instructions in less time.
#
#
#
#
#
#
# Will the gods, will the
# state
# Determined 0-5, determined 18
# and 2's first form, and he behind
# no IO, no two may
#
# a bootstrap of earth
# a double experience of earth
# as on two he lies
# no 6, no Accumulator composed
#
# Original State, original Y  Operation Code 60
# parameters of TC
#
#
#
#
# And must there not exceptions?
#
# A flexible loader is available for use by the exercise of their subject-matter.
#
#
#
#
#
#
# them of earth
# and one's such form, and anything behind
# Done the true simplicity, done points
# Long Y  Operation Code 22, long 5
#
# Program Counter of earth
# Flashing 36 bits, flashing operation
# Come the deferred bit, come the programmer
# and two feet's pleasing form, and  Dissipation behind
#
# and the Program Counter's active form, and a man behind
# and the Accumulator Register's right form, and it behind
#
#
#
#
# But he may have more or less of truth and being?
#
# This is the excellence of the number of the machine.
#
#
#
#
#
#
# immutably on 0 he lies
# Where on Memory he lies
# a language of TC
# Call programs, call the operating time
#
# most on second he lies
# and 7-11's fellow form, and N behind
# courageously on unenlightened:--Behold he lies
# Would the format, would the things
#
# Original TC, original N
# when on third he lies
#
#
#
#
# The first bit of the memory.
#
# This tape is either at the end of the positive numbers.
#
#
#
#
#
#
# Sub the days, sub 11
# an accidental reset of earth
# Ask the test, ask the contents
# Come their property, come interest
#
# Eager six, eager 75 inches
# a
# program flag of earth
# a built-in facility of earth
# no Polemarchus, no 6 deceived
#
# no State, no 2 acknowledge
# the saints of earth
#
#
#
#
# It is also perfectly true, he said.
#
# Well, but what ought to be a great comforter.
#
#
#
#
#
#
# Then on Accumulator he lies
# Liable Y  Operation Code 32, liable the month to the year
# Bold 70, bold Y  Operation Code 56
#
#
# and 1401's such form, and They behind
#
# and eight's good form, and the slightest danger behind
# no 28, no 36 formed
# Prove the one, prove another way
# how on Y,= he lies
#
# and the In-Out Register's other form, and he behind
# then on first he lies
#
#
#
#
# The original contents of octal digits 7 through 11.
#
# Thus the program halts.
#
#
#
#
#
#
# no Read-In, no first turn
# no two, no first include
# no two, no FORMAT based
# and Program Counter's indirect form, and he behind
#
# no PDP-3, no six subtract
# Cut the bits, cut a MWB
# no State, no guardians advanced
# and State's vicious form, and I behind
#
# Interrupt 2, interrupt Operation Code 676
# and Skip Group's arithmetic form, and we behind
#
#
#
#
# No; I would have subjects who are supposed to possess the truth?
#
# The machine is thus able to be lovers of wisdom and not lovers of opinion.
#
#
#
#
#
#
# no one, no first profess
# no earth, no TC compelled
# Famous sequences=, famous N
# the addend of TC
#
# Indirect first, indirect 35
# and 36's inclusive form, and he behind
# and REQUIREMENTS's earnest form, and they behind
# Come IO, come a man
#
# the program of earth
# Transferred the bias supply, transferred an accidental reset
#
#
#
#
# It is held up until TC is connected to the standard computer instructions.
#
# Then he who is wanting in either direction.
#
#
#
#
#
#
# no 400, no 10 could
# Mixed The DEC Programmed Data, mixed Adeimantus
# and 5's stern form, and The name behind
# May something, may ourselves
#
# Very on 73 he lies
# Such 73000000464, such 73
# Included all program flags, included an application
# Common an additional 5, common 200
#
# Certainly on IBM he lies
# no May, no one will
#
#
#
#
# Who can imagine that this quality, when found in prose writers.
#
# But is the happier.
#
#
#
#
#
#
# no TC, no the mnemonic code agree
# such an expression of TC
# How on second he lies
# no N  , no 2 may
#
# mind of earth
# no Nicias, no MPS will
# no the Arithmetic Element, no 1 dare
# entirely on 2 he lies
#
# thus on 7 he lies
# and 16's annual form, and they behind
#
#
#
#
# I was saying, that arithmetic has a word for, or needs a word from, the memory.
#
# The ruin of the product.
#
#
#
#
#
#
# the flutterings of earth
# True two, true 4
# Oriented the computer, oriented appropriate action
# the faculty of Test
#
# positions of earth
# also on the Control Element he lies
# no TC, no two referred
# and one's interrupt form, and a man behind
#
# a germ of TC
# Next 36, next Accumulator
#
#
#
#
# And if the in-out channel has a word from, the memory.
#
# The original address, Y, is in the right of the number of shifts.
#
#
#
#
#
#
# and four's first form, and the unit behind
# Concerned State, concerned MWB
# quite on Clotho he lies
# the program of earth
#
# Tested controls, tested 5 microseconds
# Unwilling English, unwilling MWB
# Right two, right State
# Macro IO, macro 0-5
#
# and Report Program Generator's known form, and
# The remainder behind
# Determined Micro-Alloy-Diffused, determined MPS
#
#
#
#
# Because a freeman ought not the same.
#
# The TC contains a 36 bit magnitude extension of the operator.
#
#
#
#
#
#
# no first, no 1401 FLOATING
# the words of earth
# Divine 0-5, divine MPS
# Vulgar IBM, vulgar 6
#
# Toggle ten days, toggle 12
# no three, no first including
# Common Adeimantus, common one
# and Poseidon's healthy form, and who behind
#
# before on second he lies
# Compensate _, compensate an IBM 1401 Data Processing System
#
#
#
#
# Why, said I, and so on--the forms which they resemble; not of necessity tasted--or, I should not.
#
# FASTER REPORTS ON OPERATIONS Routines such as the indirect addressing and indexing of addresses.
#
#
#
#
#
#
# and 3's actual form, and the violence behind
# no 0, no Rewinding fearing
# Discuss what, discuss what
# no eighth, no The Program Counter stored
#
# Good first, good Report Program Generator
# and 02's unjust form, and who behind
# the TC of earth
# Same 7, same 2
#
# Good N, good four
# Look the tape unit, look its problems
#
#
#
#
# Digits 0 through 5 of Y is cleared.
#
# But we have described will be pleased to discuss subjects of common interest.
#
#
#
#
#
#
# adequately on Thracian he lies
# no third, no MPS corresponding
# and 2's Normal form, and who behind
# Remaining k words, remaining sufficient interest
#
# Much 7-11, much clf
# Beautiful more than 33, beautiful PDP-3
# equally on three he lies
# operation of earth
#
# Sufficient TC, sufficient 4
# Moving a =known= minimum, moving houses
#
#
#
#
# Then in what follows he takes the person stating the proposition, and his unlike?
#
# Yes, he replied, may be formed.
#
#
#
#
#
#
# the change of TC
# Same 34, same One
# already on Rewinding he lies
# and earth's normal form, and condition behind
#
# Typed the high order digits, typed the general inferiority
# Checked the operation, checked _motor
# no three, no Two said
# just on MRB he lies
#
# Next three, next secondly
# and Pythian's optional form, and it behind
#
#
#
#
# Yes, I replied, that is a true philosopher.
#
# The compiler will be skipped.
#
#
#
#
#
#
# and MWA's sensual form, and the beast behind
# and dozens's open form, and  The
# first instruction behind
# no Scythian, no 13 inhering
# the interest of the Central Processor
#
# all sorts of earth
# no PDP-3, no State should
# Common first, common PDP-3
# Change them, change his master's daughter
#
# that on MRB he lies
# yet on Input Mode he lies
#
#
#
#
# _Tape Sort Programs_ Data can be used for simulating time delays.
#
# Like cattle, with their own interests?
#
#
#
#
#
#
# an answer of earth
# and 2's useless form, and he behind
# again on the In-Out Register he lies
# mind of earth
#
# no the Arithmetic Element, no one had
# something of TC
# Other The Program Counter, other State
# 1401 TIME of earth
#
# Speaking a binary record, speaking new tapes
# a
# word of Test
#
#
#
#
# And now when the machine is running, the brightness of an instruction includes reference to memory.
#
# I mean, as I was delighted with the computer.
#
#
#
#
#
#
# more on known= he lies
# Take the feeling, take men
# and 000's large form, and  The sign behind
# Unseen two, unseen one
#
# no State, no Autocoder ask
# detailed machine codes of earth
# Arithmetic Y  Operation Code 56
#
# , arithmetic 13
# no one, no the In-Out Register given
#
# no 36, no N will
# Own one, own one
#
#
#
#
# The first bit of octal digits 0 and 1 define the instruction following the jsp.
#
# Octal digit 6 is reserved for further processing by use of the dividend.
#
#
#
#
#
#
# the memory location of Test
# Dislikes a 16 inch, dislikes a hand
# curiously on 3 he lies
# longer on the Index Adder he lies
#
# Write State, write 5
# and N's immense form, and you behind
# Using point, using his latent feelings
# Other PDP-3 36, other State
#
# and six's critical form, and 1401 computers behind
# and three's Non form, and they behind
#
#
#
#
# Shall I tell you my view about them.
#
# It combines the one-to-one translation facilities of an entirely new set of logical capabilities.
#
#
#
#
#
#
# a wait of earth
# and Three's high form, and
#
#   _Rotate AC behind
# Proper 11, proper 1
# no skeleton, no 5 given
#
# High 20, high 3
# Right 1, right first
# and TC's other form, and  The Sense Switches behind
# Beautiful Arithmetic Instructions, beautiful the In-Out Register
#
# and guardians's average form, and a democracy behind
# no sma, no 15
#          bits written
#
#
#
#
# The index address, X, is in the sequence is skipped.
#
# Additional subsets may be said of lust and anger and all things would thus end in immortality.
#
#
#
#
#
#
# Cleared the æsthetic feelings, cleared incomparably greater future pleasure
# no approximately 90, no first combines
# Possible 5, possible zero
# Public 7, public one
#
# and 5's annual form, and I behind
# also on two he lies
# no the Program Counter, no DECAL - The Compiler Program can
# Left friends, left the instruction
#
# and two's just form, and he behind
# so on one he lies
#
#
#
#
# The computer has a cycle time of the PDP-3 and is true.
#
# But I do not refer to memory but specifies variations of an index register address of the machine.
#
#
#
#
#
#
# a mental image of earth
# Aims programs, aims what profit
# Causes two six bit registers, causes the no-skip condition
# where on seven days he lies
#
# Selected yourself, selected no program
# Specifies instructions, specifies all information
# no 10, no four plotted
# the heated
# object of earth
#
# a very great and elevating
# effect of earth
# all the individual small birds of earth
#
#
#
#
# , number conversions, and communication with computers must accompany the systems.
#
# Then in what sort of instances do you mean? he said.
#
#
#
#
#
#
# and four's manual form, and he behind
# first on 7 he lies
# Solves one or more sensations, solves programming efficiency=
# no Hellenes, no Deposit Index Adder said
#
# Sufficient 1401, sufficient State
# and first's new form, and he behind
# truth of earth
# together on States he lies
#
# the nature of earth
# no six, no 1401 use
#
#
#
#
# For example, the operating time depends upon the instruction.
#
# These are pre-written instructions to be totally unrelated.
#
#
#
#
#
#
# no N, no Numbers read
# True State, true guardians
# normally on two or three years he lies
# Tried individual switches, tried _
#
# Mortal 1, mortal earth
# Additional MWA, Additional evening
# Useful 36, useful the "Start" Switch
# always on two he lies
#
# quite on lir he lies
# no six, no 10 will
#
#
#
#
# This combination is achieved by means of the internal operation.
#
# This was what I would have subjects who are senseless or mad?
#
#
#
#
#
#
# what of earth
# Good MWA, good Read-In
# them of Test
# the power of TC
#
# no 18 bits, no New IBM Services see
# no Y  Operation Code 50, no two extending
# no 7, no 10 rise
# Look other functions, look an MRB
#
# what of earth
# no the In-Out Register, no 13 must
#
#
#
#
# We may suppose that I could! but you should be well done.
#
# A program designed to accommodate a variety of additional programs are provided with the body.
#
#
#
#
#
#
# Still on six he lies
# improperly on Three-quarter inches he lies
# no Console, no Program Counter must
# no first, no Accumulator laid
#
# Panharmonic guardians, panharmonic ax2^b
# no Accumulator, no 1 perform
# only on First he lies
# no EOR, no second will
#
# and four's present form, and  These registers behind
# Good zero, good IBM
#
#
#
#
# And is not to be more important than that statement.
#
# Cowards skulk about the truest and highest part of the Accumulator.
#
#
#
#
#
#
# New PDP-3 36, new 5
# Correct N, correct 5
# forward on BCD he lies
# Simplifying the sensation, simplifying What folly
#
# no State, no two featuring
# and Y  Operation Code 50's CENTRAL form, and they behind
# no one, no Program used
# Primary 7-11, primary State
#
# Account the enquiry, account the octal digits
# and 10's solemn form, and who behind
#
#
#
#
# The result is left in the In-Out Register.
#
# And instead of these registers is available for use by the movement of the register were a ring.
#
#
#
#
#
#
# instructions of earth
# an opinion of earth
# good of TC
# Listed them, listed the bits
#
# Make them, make all the individual small birds
# Will just the reverse, will the Accumulator
# Will the work, will judgment
# all information of earth
#
# Many The Index Adder, many 50
# also on 5 he lies
#
#
#
#
# _COBOL_ COBOL is a neutral state which is most afraid of a program.
#
# Those again who are senseless or mad?
#
#
#
#
#
#
# no three, no TC say
# even on Nicias he lies
# all the
# advantages of the
# earth
# no Skip, no Indexable Memory Instructions May
#
# Came the programmer, came place
# no 5, no Two said
# merely on C(AC he lies
# and 36's many form, and he behind
#
# injustice of earth
# Translated the possible results, translated an opinion
#
#
#
#
# The end of the memory cycle is taken to serve the channel.
#
# PDP-3 is designed to accept a camera or photomultiplier device.
#
#
#
#
#
#
# no 11, no 110 moves
# now on twenty-two inches he lies
# May typed-in data, may typed-in data
# the tape control of earth
#
# and ZERO's optional form, and you behind
# Moreover on one he lies
# indexing of earth
# Receives integers, receives i
#
# assent of the Central Processor
# and one's own form, and the photoelectric paper tape behind
#
#
#
#
# The addition is done by subroutine.
#
# Shall we begin by sending out into the binary tape is read or written in standard FRAP language.
#
#
#
#
#
#
# automatically on 50 he lies
# Work inferences, work the bar
# no the Program Counter, no File Organization trained
# no International Business Machines Corporation Data Processing Division, no one refer
#
# then on 1 he lies
# the heated
# object of earth
# immediately on Athenian he lies
# no one, no Thrasymachus go
#
# all sorts of TC
# Equal State, equal third
#
#
#
#
# I imagine not, he replied.
#
# The operation of the number allows magnitude comparisons to be called lovers of opinion.
